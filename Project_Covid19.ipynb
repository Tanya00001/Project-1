# %%
import pandas as pd

# %%
cov19 = pd.read_csv("covid.csv")

# %%
# Having a glance at some of the records.
cov19.head(10)
# Out:
#   iso_code location        date  total_cases  new_cases  total_deaths  \
# 0      ABW    Aruba  2020-03-13            2          2             0
# 1      ABW    Aruba  2020-03-20            4          2             0
# 2      ABW    Aruba  2020-03-24           12          8             0
# 3      ABW    Aruba  2020-03-25           17          5             0
# 4      ABW    Aruba  2020-03-26           19          2             0
# 5      ABW    Aruba  2020-03-27           28          9             0
# 6      ABW    Aruba  2020-03-28           28          0             0
# 7      ABW    Aruba  2020-03-29           28          0             0
# 8      ABW    Aruba  2020-03-30           50         22             0
# 9      ABW    Aruba  2020-04-01           55          5             0
#
#    new_deaths  total_cases_per_million  new_cases_per_million  \
# 0           0                   18.733                 18.733
# 1           0                   37.465                 18.733
# ...

# %%
# Looking at the shape(total no. of rows and columns)
cov19.shape
# Out:
# (19496, 32)

# %%
# Looking at the different locations
cov19["location"].value_counts()
# Out:
# Austria           146
# Brazil            146
# Russia            146
# Lithuania         146
# China             146
#                  ...
# Yemen              45
# Western Sahara     29
# Tajikistan         24
# Comoros            23
# Lesotho            10
# Name: location, Length: 212, dtype: int64

# %%
# Checking if columns have Null values
cov19.isna().any()
# Out:
# iso_code                            True
# location                           False
# date                               False
# total_cases                        False
# new_cases                          False
# total_deaths                       False
# new_deaths                         False
# total_cases_per_million             True
# new_cases_per_million               True
# total_deaths_per_million            True
# new_deaths_per_million              True
# total_tests                         True
# new_tests                           True
# total_tests_per_thousand            True
# new_tests_per_thousand              True
# new_tests_smoothed                  True
# new_tests_smoothed_per_thousand     True
# tests_units                         True
# stringency_index                    True
# population                          True
# population_density                  True
# median_age                          True
# aged_65_older                       True
# ...

# %%
# Getting the sum of Null values across each column
cov19.isna().sum()
# Out:
# iso_code                              64
# location                               0
# date                                   0
# total_cases                            0
# new_cases                              0
# total_deaths                           0
# new_deaths                             0
# total_cases_per_million              377
# new_cases_per_million                377
# total_deaths_per_million             377
# new_deaths_per_million               377
# total_tests                        14332
# new_tests                          14904
# total_tests_per_thousand           14332
# new_tests_per_thousand             14904
# new_tests_smoothed                 13866
# new_tests_smoothed_per_thousand    13866
# tests_units                        13267
# stringency_index                    4500
# population                            64
# population_density                   850
# median_age                          1743
# aged_65_older                       1980
# ...

# %%
# Getting the cases in India
India_cases = cov19[cov19["location"] == "India"]

# %%
India_cases.head(40)
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8379      IND    India  2019-12-31            0          0             0
# 8380      IND    India  2020-01-01            0          0             0
# 8381      IND    India  2020-01-02            0          0             0
# 8382      IND    India  2020-01-03            0          0             0
# 8383      IND    India  2020-01-04            0          0             0
# 8384      IND    India  2020-01-05            0          0             0
# 8385      IND    India  2020-01-06            0          0             0
# 8386      IND    India  2020-01-07            0          0             0
# 8387      IND    India  2020-01-08            0          0             0
# 8388      IND    India  2020-01-09            0          0             0
# 8389      IND    India  2020-01-10            0          0             0
# 8390      IND    India  2020-01-11            0          0             0
# ...

# %% [markdown]
# #### _As we can see, in India, cases started from 30th of Jan 2020, total and new cases were only 1 with 0 death._

# %%
# Last 5 days cases in India
India_cases.tail()
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8519      IND    India  2020-05-20       106750       5611          3303
# 8520      IND    India  2020-05-21       112359       5609          3435
# 8521      IND    India  2020-05-22       118447       6088          3583
# 8522      IND    India  2020-05-23       125101       6654          3720
# 8523      IND    India  2020-05-24       131868       6767          3867
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8519         140                   77.355                  4.066
# 8520         132                   81.419                  4.064
# 8521         148                   85.831                  4.412
# 8522         137                   90.653                  4.822
# 8523         147                   95.556                  4.904
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %% [markdown]
# #### _Last day total cases had reached at 1,31,868 and new cases on that day were 6,767. Total deaths on last day were 3,867 with 147 new deaths._

# %%
import seaborn as sns

# %%
# Total cases per day, in India

sns.set_theme(color_codes=True, style='darkgrid', palette = "rainbow")
sns.set(rc = {'figure.figsize': (10,10)})

sns.lineplot(x = "date", y = "total_cases", data = India_cases )
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_cases'>

# %%
# Making a dataset for last 5 days cases in India

India_5 = India_cases.tail()

# %%
India_5
# Out:
#      iso_code location        date  total_cases  new_cases  total_deaths  \
# 8519      IND    India  2020-05-20       106750       5611          3303
# 8520      IND    India  2020-05-21       112359       5609          3435
# 8521      IND    India  2020-05-22       118447       6088          3583
# 8522      IND    India  2020-05-23       125101       6654          3720
# 8523      IND    India  2020-05-24       131868       6767          3867
#
#       new_deaths  total_cases_per_million  new_cases_per_million  \
# 8519         140                   77.355                  4.066
# 8520         132                   81.419                  4.064
# 8521         148                   85.831                  4.412
# 8522         137                   90.653                  4.822
# 8523         147                   95.556                  4.904
#
#       total_deaths_per_million  ...  aged_65_older  aged_70_older  \
# ...

# %%
# Last 5 days total cases

sns.lineplot(x = "date", y = "total_cases", data = India_5)
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_cases'>

# %%
# Now, let's check the test scenario as well
# checking the columns name....

India_cases.columns
# Out:
# Index(['iso_code', 'location', 'date', 'total_cases', 'new_cases',
#        'total_deaths', 'new_deaths', 'total_cases_per_million',
#        'new_cases_per_million', 'total_deaths_per_million',
#        'new_deaths_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand', 'tests_units',
#        'stringency_index', 'population', 'population_density', 'median_age',
#        'aged_65_older', 'aged_70_older', 'gdp_per_capita', 'extreme_poverty',
#        'cvd_death_rate', 'diabetes_prevalence', 'female_smokers',
#        'male_smokers', 'handwashing_facilities', 'hospital_beds_per_100k'],
#       dtype='object')

# %%
# checking total tests happened in India

sns.lineplot(x = "date", y = "total_tests", data = India_cases)
# Out:
# <AxesSubplot:xlabel='date', ylabel='total_tests'>

# %% [markdown]
# #### Surely, at higher rate..
# #### As we can see tests happened at higher rate, In beginning, it was low but as the cases started increasing tests were happened accordingly.

# %%
sns.regplot(x = "total_cases", y = "total_tests", data = India_cases, color = "r")
# Out:
# <AxesSubplot:xlabel='total_cases', ylabel='total_tests'>

# %% [markdown]
# #### _Positive trend.._

# %% [markdown]
# #### Here, we can clearly observe the increasing total tests according to the increasing total cases.

# %%
# last day cases, in the whole world

Last = cov19[cov19["date"] == "2020-05-24"]

# %%
Last
# Out:
#        iso_code      location        date  total_cases  new_cases  \
# 62          ABW         Aruba  2020-05-24          101          0
# 198         AFG   Afghanistan  2020-05-24         9998        782
# 262         AGO        Angola  2020-05-24           60          0
# 321         AIA      Anguilla  2020-05-24            3          0
# 398         ALB       Albania  2020-05-24          989          8
# ...         ...           ...         ...          ...        ...
# 19045       YEM         Yemen  2020-05-24          212          7
# 19153       ZAF  South Africa  2020-05-24        21343       1218
# 19220       ZMB        Zambia  2020-05-24          920          0
# 19285       ZWE      Zimbabwe  2020-05-24           56          0
# 19431  OWID_WRL         World  2020-05-24      5273572      97636
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 62                3           0                  945.994
# ...

# %%
# Sorting this dataset

Max = Last.sort_values(by = "total_cases", ascending = False)
Max
# Out:
#        iso_code                         location        date  total_cases  \
# 19431  OWID_WRL                            World  2020-05-24      5273572
# 18391       USA                    United States  2020-05-24      1622670
# 2655        BRA                           Brazil  2020-05-24       347398
# 15569       RUS                           Russia  2020-05-24       335882
# 9396        ITA                            Italy  2020-05-24       229327
# ...         ...                              ...         ...          ...
# 18723       VGB           British Virgin Islands  2020-05-24            8
# 1645        BES  Bonaire Sint Eustatius and Saba  2020-05-24            6
# 5543        ESH                   Western Sahara  2020-05-24            6
# 321         AIA                         Anguilla  2020-05-24            3
# 11086       LSO                          Lesotho  2020-05-24            2
#
#        new_cases  total_deaths  new_deaths  total_cases_per_million  \
# ...

# %%
# Top 5 countries with maximum cases

Top_5 = Max[1:6]
Top_5
# Out:
#       iso_code       location        date  total_cases  new_cases  \
# 18391      USA  United States  2020-05-24      1622670      21236
# 2655       BRA         Brazil  2020-05-24       347398      16508
# 15569      RUS         Russia  2020-05-24       335882       9434
# 9396       ITA          Italy  2020-05-24       229327        669
# 4613       DEU        Germany  2020-05-24       178281        431
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 18391         97087        1080                 4902.287
# 2655          22013         965                 1634.357
# 15569          3388         139                 2301.595
# 9396          32735         119                 3792.922
# 4613           8247          31                 2127.866
#
#        new_cases_per_million  total_deaths_per_million  ...  aged_65_older  \
# 18391                 64.157                   293.312  ...         15.413
# ...

# %%
sns.barplot(x = "location", y = "total_cases", data = Top_5, hue = "location")
# Out:
# <AxesSubplot:xlabel='location', ylabel='total_cases'>

# %%
Top = cov19[(cov19["location"] == "United States") | (cov19["location"] == "Brazil") | (cov19["location"] == "Russia") | (cov19["location"] == "Italy") | (cov19["location"] == "Germany")]

# %%
sns.barplot(x = "location", y = "total_cases", data = Top, hue = "date")
sns.set(rc = {'figure.figsize': (10,10)})

# %% [markdown]
# #### _Here, we can understand the cases of Top 5 countries._

# %%
# Understanding cases of India and China.

I_C = cov19[(cov19["location"] == "India") | (cov19["location"] == "China")]

# %%
sns.barplot(x = "location", y = "total_cases", data = I_C, hue = "date")
sns.set(rc = {'figure.figsize': (20,20)})

# %% [markdown]
# #### If we will look at the BarPlot, in China, cases were increasing from the first day and cases were higher and higher because the Covid-19 first identified at Wuhan City, China, from there it began spreading all over the World. But, in India, cases were few in the beginning, and gradually started increasing.

# %%
# For the sake of ease, dropping NaN values.

data1 = cov19.dropna()
data1
# Out:
#       iso_code      location        date  total_cases  new_cases  \
# 1730       BGD    Bangladesh  2020-03-15            3          0
# 1732       BGD    Bangladesh  2020-03-17            5          2
# 1733       BGD    Bangladesh  2020-03-18            8          3
# 1734       BGD    Bangladesh  2020-03-19           10          2
# 1735       BGD    Bangladesh  2020-03-20           10          0
# ...        ...           ...         ...          ...        ...
# 19147      ZAF  South Africa  2020-05-18        15515       1160
# 19274      ZWE      Zimbabwe  2020-05-13           37          0
# 19277      ZWE      Zimbabwe  2020-05-16           42          5
# 19278      ZWE      Zimbabwe  2020-05-17           44          2
# 19279      ZWE      Zimbabwe  2020-05-18           46          2
#
#        total_deaths  new_deaths  total_cases_per_million  \
# 1730              0           0                    0.018
# 1732              0           0                    0.030
# ...

# %%
# Some countries data are available, those having prevalence of diabetes.


P = sns.barplot(x = "location", y = "diabetes_prevalence", data = data1)
P.set_xticklabels(P.get_xticklabels(), rotation = 40);

# %% [markdown]
# #### _China's data is not available in this dataset, but China is the country with highest number of diabetics worldwide, with around 116 million people suffering from the disease._
#
#
#
# ### According to WHO(World Health Organization), diabetes is the leading cause of death in Mexico. We can observe this thing in the above BarPlot.

# %%
# Countries having more people aged 70 older.

P = sns.barplot(x = "location", y = "aged_70_older", data = data1)
P.set_xticklabels(P.get_xticklabels(), rotation = 40);

# %% [markdown]
# #### Costa Rice will become a super-aged society in the year 2045 when 21% of the population will have reached the age of 65 or older.
#
#
# #### According to the United Nation's projection, the number of older adults in Costa Rice will triple by 2050 to roughly 1.37 million.

# %%
# Countries having handwashing facilities.

P = sns.barplot(x = "location", y = "handwashing_facilities", data = data1)
P.set_xticklabels(P.get_xticklabels(), rotation = 40);

# %%
# Statistical data

cov19.describe()
# Out:
#         total_cases      new_cases   total_deaths    new_deaths  \
# count  1.949600e+04   19496.000000   19496.000000  19496.000000
# mean   1.752634e+04     540.990152    1162.475739     35.055601
# std    1.808525e+05    4858.071697   12377.578661    334.755956
# min    0.000000e+00   -2461.000000       0.000000      0.000000
# 25%    5.000000e+00       0.000000       0.000000      0.000000
# 50%    8.400000e+01       2.000000       1.000000      0.000000
# 75%    1.135250e+03      43.000000      24.000000      1.000000
# max    5.273572e+06  107909.000000  341722.000000  10520.000000
#
#        total_cases_per_million  new_cases_per_million  \
# count             19119.000000           19119.000000
# mean                499.008529              13.312513
# std                1458.509832              63.749619
# min                   0.000000            -265.189000
# 25%                   0.593000               0.000000
# 50%                  26.720000               0.246000
# ...

# %% [markdown]
# #### _Here, we can see the data like average total cases, new cases.., standard deviation, minimum value and maximum value in dataset, percentile(25%, 50%, and 75%) value and so on.._
